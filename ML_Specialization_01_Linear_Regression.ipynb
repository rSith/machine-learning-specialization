# %% [markdown]
# <a href="https://colab.research.google.com/github/rSith/machine-learning-specialization/blob/main/ML_Specialization_01_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01. Model Representation
# > Learn to implement the model $f_{w,b}$ for linear regression with one variable

# %% [markdown]
# ## Notation
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Tools
# > - NumPy : Library for Scientific computing
# > - Matplotlib : Library for plotting data

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ## Problem Statment
# > Using a simple dataset with only two data points - a house with 1000 square feet(sqft) sold for \$300,000 and a house with 2000 sqft sold for $500,000.
# These two points will constityte our data or training set.

# %%
# x_train is the input variable (size in 1000 square feet)
# y_train is the target (price in 1000 of dollors)

x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])

print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %% [markdown]
# ## Number of training examples $m$
# > Use $m$ to denote the number of training examples.
# - NumPy arrays have `.shape()` parameter.
# - `x_train.shape` returns a python tuple with an entry of each dimenstion.
# - `x_train.shappe[0]` is the length of the array and number of examples

# %%
# m is the number of training examples

print(f"x_train.shape: {x_train.shape}")

m = x_train.shape[0]

print(f"Number of training examples is : {m}")
# Out:
# x_train.shape: (2,)
# Number of training examples is : 2

# %% [markdown]
# - Also can use the Python `len()` function

# %%
m = len(x_train)
print(f"Number of training examples is : {m}")
# Out:
# Number of training examples is : 2

# %% [markdown]
# ## Trianing example `x_i, y_i`
# > You will use (x$^{(i)}$, y$^{(i)}$) to denote the $i^{th}$ training example. Since Python is zero indexed, (x$^{(0)}$, y$^{(0)}$) is (1.0, 300.0) and (x$^{(1)}$, y$^{(1)}$) is (2.0, 500.0).
#
# To access a value in a Numpy array, one indexes the array with the desired offset. For example the syntax to access location zero of `x_train` is `x_train[0]`.

# %%
i = 0

x_i = x_train[i]
y_i = y_train[i]

print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(0), y^(0)) = (1.0, 300.0)

# %%
i = 1

x_i = x_train[i]
y_i = y_train[i]

print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(1), y^(1)) = (2.0, 500.0)

# %% [markdown]
# ## Plotting the data
# > use `scatter()` function in the `matplotlib` library.
# - the function arguments `marker` and `c` show the points as red crosses

# %%
#plot the data points
plt.scatter(x_train, y_train, marker='x', c='r')

#Set the title
plt.title("Housing Prices")

#Set the y-axis label
plt.ylabel('Price(in 1000s of dollors)')
# Set the -asix label
plt.xlabel('Soze(1000 sqft)')

plt.show()

# %% [markdown]
# ## Model Function
# the model function for linear regression (which is a function that maps from `x` to `y`) is represented as
#
# $$ f_{w,b}(x^{(i)}) = wx^{(i)} + b $$
#
# The formula above is how you can represent straight lines - different values of $w$ and $b$ give you different straight lines on the plot.

# %%
# Let's strat with w = 100 and b = 100
w = 100
b = 100

print(f"w: {w}")
print(f"b: {b}")
# Out:
# w: 100
# b: 100

# %% [markdown]
# ### Compute the value of $f_{w,b}(x^{(i)})$ for data points.
# > for large number of data points calculate the function output in a `for` loop as shown in `compute_model_output` function
# - `(ndarray(m,))` describes a Numpy n-dimensional array of shape m.
# - `(scalar)` describes an argument without dimensions
# - `np.zero(n)` will return a one-dimensional numpy array with n entries.

# %%
"""Computes the prediction of a linear model
   Arguments :
   x (ndarray (m,)): Data, m examples
   w, b (scalar)  : model parameters
   Returns
   f_wb (ndarray (m,)): model prediction
"""

def compute_model_output(x, w, b):
  m = x.shape[0]
  f_wb = np.zeros(m)
  for i in range(m):
      f_wb[i] = w * x[i] + b

  return f_wb

# %%
tmp_f_wb = compute_model_output(x_train, w, b)

# Plot our model prediction
plt.plot(x_train, tmp_f_wb, c='b', label='Our predctions')

# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r', label='Actual Values')

# Set the title
plt.title("Housing Prices")

# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')

# Set the x-axis label
plt.xlabel('Size (1000 sqft)')

plt.legend()
plt.show()

# %% [markdown]
# Setting $w = 100$ and $b = 100$ does not result in a line that fits our data.
# > Use different values of $w$ and $b$ to check the line will fits for data.

# %%
# Let's strat with w = 100 and b = 100
w = 200
b = 100

print(f"w: {w}")
print(f"b: {b}")
# Out:
# w: 200
# b: 100

# %%
tmp_f_wb = compute_model_output(x_train, w, b)

# Plot our model prediction
plt.plot(x_train, tmp_f_wb, c='b', label='Our predctions')

# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r', label='Actual Values')

# Set the title
plt.title("Housing Prices")

# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')

# Set the x-axis label
plt.xlabel('Size (1000 sqft)')

plt.legend()
plt.show()

# %% [markdown]
# ## Prediction
# Now we have a model, we can use it to make our original prection.
# > Let's predict the price of a house with 1200 sqft. (Since the units of $x$ are in 1000's of sqft, $x$ is 1.2)

# %%
w = 200
b = 100
x_i = 1.2

cost_1200sqft = w * x_i + b

print(f"Price of a house with 1200 sqft = ${cost_1200sqft}")
# Out:
# Price of a house with 1200 sqft = $340.0

# %% [markdown]
# What I have Learned :
# - Linear regression builds a model which establishes a relationhip between features and targets.
#   - in the example above, the feacture was house size and the target was house price.
#   - for simple linear regression, the model has two parameters $w$ and $b$ whose values are 'fit' using traning data.
#   - Once a model's parameters have been determined, the model can be used to make predictions on novel data.
#
#
# ---

# %% [markdown]
# # 02. Cost Function : Squared error cost function
#
# > Implement and explore the cost function for linear regression with one variable

# %% [markdown]
# ## Computing Cost
# > Cost is a measure of how well our model is predicting the traget price of the house. The tearm 'price' is used for housing data.
#
# **Equation for cost with one variable :**
#
#   $$J(w,b) = \frac{1}{2m} \sum\limits_{i = 0}^{m-1} (f_{w,b}(x^{(i)}) - y^{(i)})^2 \tag{1}$$
#
# where
#   $$f_{w,b}(x^{(i)}) = wx^{(i)} + b \tag{2}$$
#
# - $f_{w,b}(x^{(i)})$ is our prediction for example $i$ using parameters $w,b$.
# - $(f_{w,b}(x^{(i)}) -y^{(i)})^2$ is the squared difference between the target value and the prediction.
# - These differences are summed over all the $m$ examples and divided by `2m` to produce the cost, $J(w,b)$.
# >ranges are typically from 1 to m, while code will be from 0 to m-1.

# %%
def compute_cost(x, y, w, b):

  # number of training examples
  m = x.shape[0]

  cost_sum = 0 # Initialize cost_sum here
  # compute cost

  for i in range(m):
    f_wb = w * x[i] + b
    cost = (f_wb - y[i]) ** 2
    cost_sum = cost_sum + cost
  total_cost = (1/(2 * m)) * cost_sum

  return total_cost

# %% [markdown]
# ## Cost function Intuition
# > - goal is to find a model $f_{w,b}(x) = wx + b$, with parameters $w,b$,  which will accurately predict house values given an input $x$.
# - The cost is a **measure of how accurate the model** is on the training data.
#
# - The cost equation (1) above shows that if $w$ and $b$ can be selected such that the predictions $f_{w,b}(x)$ match the target data $y$, the $(f_{w,b}(x^{(i)}) - y^{(i)})^2 $ term will be zero and the cost minimized.
#
# Previous, you determined that $b=100$ provided an optimal solution so let's set $b$ to 100 and focus on $w$.

# %% [markdown]
# - The Cost equation provides a measure of how well your predictions match your training data.
# - Minimizing the cost can provide optimal values of $w$, $b$

# %% [markdown]
# ![Screenshot 2026-09-10 234700.png](data:image/png;base64,...)![Screenshot 2026-09-10 234327.png](data:image/png;base64,...)![Screenshot 2026-09-10 234621.png](data:image/png;base64,...)

# %% [markdown]
# - Cost is minimized when 2 = 200
# - Because the difference between the traget and prediction is squared in the cost equation, the cost increases rapidly when $w$ is either too large or too small.
# - Using the $w$ and $b$ selected by minimizing cost results in a line which is a perfecr fit to the data.

# %% [markdown]
# ### Cost function visualization
# ![Screenshot 2026-09-10 235756.png](data:image/png;base64,...)![Screenshot 2026-09-10 235939.png](data:image/png;base64,...)![Screenshot 2026-09-10 235900.png](data:image/png;base64,...)

# %% [markdown]
# ### Convex Cost Surface
# > - The cost function squares the loss ensures that the 'error surface' is converx like a soup bowl.
# > - It always have a minimum that can be reached by following the gradient in all dimenstions.
#
# ![Screenshot 2026-09-11 000732.png](data:image/png;base64,...)

# %% [markdown]
# ## What I have learned:
# >- The cost equation provides a measure of how well your predictions match your training data.
# >- Minimizing the cost can provide optimal values of $w$, $b$

# %% [markdown]
# # 03. Gradient Descent for Linear Regression
# > **Goal:** Automate the process of potimizing $w$ and $b$ using gradient descent.

# %%
import math, copy

# %% [markdown]
# we have developed a linear model that predicts $f_{w,b}(x^{(i)})$:
# $$f_{w,b}(x^{(i)}) = wx^{(i)} + b \tag{1}$$
# - In linear regression, you utilize input training data to fit the parameters $w$,$b$ by **minimizing a measure of the error** between our **predictions** $f_{w,b}(x^{(i)})$ and the **actual data** $y^{(i)}$. The measure is called the $cost$, $J(w,b)$.
# - In training you measure the cost over all of our training samples $x^{(i)},y^{(i)}$
# $$J(w,b) = \frac{1}{2m} \sum\limits_{i = 0}^{m-1} (f_{w,b}(x^{(i)}) - y^{(i)})^2\tag{2}$$

# %% [markdown]
# *gradient descent* was described as:
#
# $$\begin{align*} \text{repeat}&\text{ until convergence:} \; \lbrace \newline
# \;  w &= w -  \alpha \frac{\partial J(w,b)}{\partial w} \tag{3}  \; \newline
#  b &= b -  \alpha \frac{\partial J(w,b)}{\partial b}  \newline \rbrace
# \end{align*}$$
# where, parameters $w$, $b$ are updated simultaneously.
# The gradient is defined as:
# $$
# \begin{align}
# \frac{\partial J(w,b)}{\partial w}  &= \frac{1}{m} \sum\limits_{i = 0}^{m-1} (f_{w,b}(x^{(i)}) - y^{(i)})x^{(i)} \tag{4}\\
#   \frac{\partial J(w,b)}{\partial b}  &= \frac{1}{m} \sum\limits_{i = 0}^{m-1} (f_{w,b}(x^{(i)}) - y^{(i)}) \tag{5}\\
# \end{align}
# $$
#
# Here *simultaniously* means that you calculate the partial derivatives for all the parameters before updating any of the parameters.

# %% [markdown]
# ## Implement Gradient Descent
# > Need three functions.
# - `compute_gradient` : to implementing equation (4) and (5)
# - `compute_cost` : implementing equation (2)
# - `gradient_descent` : utilizing `compute_gradient` and `compute_cost`

# %%
def compute_gradient(x, y, w, b):
  # Number of training examples
  m = x.shape[0]

  dj_dw = 0
  dj_db = 0

  for i in range(m):
    f_wb = w * x[i] + b
    dj_dw_i = (f_wb - y[i]) * x[i]
    dj_db_i = f_wb - y[i]
    dj_dw += dj_dw_i
    dj_db += dj_db_i

  dj_dw = dj_dw / m
  dj_db = dj_db / m

  return dj_dw, dj_db

# %% [markdown]
# - Gradient descent utilizes the partial derivative of the cost with respect to a parameter at a point to update that parameter.
# - By using `compute_gradient` function plot some partial derivatives of our cost function relative to one of the parameters, $w_0$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Left plot shows $\frac{\partial J(w,b)}{\partial w}$ or the slope of the cost curve relative to $w$ at three points. On the right side of the plot, the derivative is positive, while on the left it is negative. Due to the 'bowl shape', the derivatives will always lead gradient descent toward the bottom where the gradient is zero.
#
# - The left plot has fixed $b=100$. Gradient descent will utilize both $\frac{\partial J(w,b)}{\partial w}$ and $\frac{\partial J(w,b)}{\partial b}$ to update parameters.
# - The 'quiver plot' on the right provides a means of viewing the gradient of both parameters. The arrow sizes reflect the magnitude of the gradient at that point. The direction and slope of the arrow reflects the ratio of $\frac{\partial J(w,b)}{\partial w}$ and $\frac{\partial J(w,b)}{\partial b}$ at that point.
#
# > Note that the gradient points *away* from the minimum. Review equation (3) above. The scaled gradient is *subtracted* from the current value of $w$ or $b$. This moves the parameter in a direction that will reduce cost.

# %%
def gradient_descent(x, y, w_in, b_in, alpha, num_iters, cost_function, gradient_function):

  # An array to store cost J and w's at each iteration primarily for graphing later
  J_history = []
  p_history = []
  b = b_in
  w = w_in

  for i in range(num_iters):
    # Calculate the gradient and update the parameters using gradient_function
    dj_dw, dj_db = gradient_function(x, y, w, b)

    # Update Parameters using equation (3) above
    b = b - alpha * dj_db
    w = w - alpha * dj_dw

    # Save cost J at each iteration
    if i<100000:    # prevent resource exhaustion
      J_history.append( cost_function(x, y, w, b) )
      p_history.append([w,b])
    # Print cost every at intervals 10 times or as many iterations if < 10
    if i% math.ceil(num_iters/10) == 0:
      print(f"Iteration{i:4}: Cost {J_history[-1]:0.2e}",
            f"dj_dw: {dj_dw: 0.3e}, dj_db: {dj_db: 0.3e}",
            f"w:{w: 0.3e}, b:{b: 0.5e}")

  return w, b, J_history, p_history #return w and J,w history for graphing

# %%
import math

# initialize parameters
w_init = 0
b_init = 0
# some gradient descent settings
iterations = 10000
tmp_alpha = 1.0e-2
# run gradient descent
w_final, b_final, J_hist, p_hist = gradient_descent(x_train ,y_train, w_init, b_init, tmp_alpha,
                                                    iterations, compute_cost, compute_gradient)
print(f"(w,b) found by gradient descent: ({w_final:8.4f},{b_final:8.4f})")
# Out:
# Iteration   0: Cost 7.93e+04 dj_dw: -6.500e+02, dj_db: -4.000e+02 w: 6.500e+00, b: 4.00000e+00
# Iteration1000: Cost 3.41e+00 dj_dw: -3.712e-01, dj_db:  6.007e-01 w: 1.949e+02, b: 1.08228e+02
# Iteration2000: Cost 7.93e-01 dj_dw: -1.789e-01, dj_db:  2.895e-01 w: 1.975e+02, b: 1.03966e+02
# Iteration3000: Cost 1.84e-01 dj_dw: -8.625e-02, dj_db:  1.396e-01 w: 1.988e+02, b: 1.01912e+02
# Iteration4000: Cost 4.28e-02 dj_dw: -4.158e-02, dj_db:  6.727e-02 w: 1.994e+02, b: 1.00922e+02
# Iteration5000: Cost 9.95e-03 dj_dw: -2.004e-02, dj_db:  3.243e-02 w: 1.997e+02, b: 1.00444e+02
# Iteration6000: Cost 2.31e-03 dj_dw: -9.660e-03, dj_db:  1.563e-02 w: 1.999e+02, b: 1.00214e+02
# Iteration7000: Cost 5.37e-04 dj_dw: -4.657e-03, dj_db:  7.535e-03 w: 1.999e+02, b: 1.00103e+02
# Iteration8000: Cost 1.25e-04 dj_dw: -2.245e-03, dj_db:  3.632e-03 w: 2.000e+02, b: 1.00050e+02
# Iteration9000: Cost 2.90e-05 dj_dw: -1.082e-03, dj_db:  1.751e-03 w: 2.000e+02, b: 1.00024e+02
# ...

# %% [markdown]
# **Characteristics of the gradient descent process printed above:**
# - The cost starts large and rapidly decline.
# - The partial derivatives, `dj_dw`, and `dj_db` also get smaller, rapidly at first and then more slowly.
# - the progress slows though the learning rate, alpha, remain fixed.

# %% [markdown]
# ## Cost versus iterations of Gradient Descent
# > - A plot of cost versus iterations is usedul measure of progress in gradient descent. Cost should always decrease in successful runs.
# > - The change in cost is so rapid initially, it is useful to plot the initial decent on a differnt scale than the final descent.

# %%
# plot cost versus iteration
fig, (ax1, ax2) = plt.subplots(1, 2, constrained_layout=True, figsize=(12,4))
ax1.plot(J_hist[:100])
ax2.plot(1000 + np.arange(len(J_hist[1000:])), J_hist[1000:])
ax1.set_title("Cost vs. iteration(start)");  ax2.set_title("Cost vs. iteration (end)")
ax1.set_ylabel('Cost')            ;  ax2.set_ylabel('Cost')
ax1.set_xlabel('iteration step')  ;  ax2.set_xlabel('iteration step')
plt.show()

# %% [markdown]
# ## Predictions
# > Now we have discovered the optimal values for the parameters $w$ and $b$, we now can use the model to predict housing values based on our learned parameters.
# As expected, the predicted values are nearly the same as the training values for the same housing. Further, the value not in the prediction is in line with the expected value.

# %%
print(f"1000 sqft house prediction {w_final*1.0 + b_final:0.1f} Thousand dollars")
print(f"1200 sqft house prediction {w_final*1.2 + b_final:0.1f} Thousand dollars")
print(f"2000 sqft house prediction {w_final*2.0 + b_final:0.1f} Thousand dollars")
# Out:
# 1000 sqft house prediction 300.0 Thousand dollars
# 1200 sqft house prediction 340.0 Thousand dollars
# 2000 sqft house prediction 500.0 Thousand dollars

# %% [markdown]
# ## Plotting
# > We can show the progress of gradient descent during its execution by plotting the cost over iterations on a contour plot of the cost(w,b)
